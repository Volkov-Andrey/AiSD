# %%
#№6.1.2
print('Введите длины катета, а затем - гипотенузы через пробел')
b, c = map(int, input().split())
if b > 0 and c > 0 and c > b:
    def cathetus_2(b, c):
        return ((c**2 - b**2)**0.5)
    print(cathetus_2(b, c))
elif b <= 0 or c <= 0:
    raise ValueError('длины сторон треугольника не могут быть неположительны! проверьте корректность введеных данных!')
elif c < b:
    raise ValueError('катет не может быть длиннее гипотенузы! проверьте корректность введеных данных!')
# Out:
# Введите длины катета, а затем - гипотенузы через пробел
# 3 5
# 4.0

# %%
#№6.1.1
my_list = [0, 1, 2, 3, 4]
iterator = iter(my_list)

while True:
    try:
        item = next(iterator)
        print(item)
    except StopIteration:
        break
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
#№6.1.4
try:
    filename = input("Введите имя файла: ")
    with open(filename, 'r') as file:
        first_line = file.readline()
        print("Первая строка из файла:", first_line)
except FileNotFoundError:
    print("Файл не найден")
except Exception as e:
    print("Произошла ошибка:", e)
# Out:
# Введите имя файла: asd.txt
# Первая строка из файла: Ђ}q(jjqwir37qKXdsakl;dqKXdasdqKX

# %%
#№6.2.2
def show_file_content(file_name, max_lines=None):
    with open('qwerty1.txt', 'r') as file:
        lines = file.readlines()
        if max_lines is not None:
            lines = lines[:max_lines]
        for line in lines:
            print(line, end='')
print(show_file_content("example.txt", 2))
# Out:
# asdas
# dasads
# None

# %%
#№6.2.3
def word_statistics(filename):
    word_stat = {}
    with open(filename, 'r') as file:
        text = file.read()
        punctuations = '''!()-[]{};:'"\,<>./?@#$%^&*_~'''
        for ch in text:
            if ch in punctuations:
                text = text.replace(ch, " ")
        text = text.lower()
        words = text.split()
        
        for word in words:
            if word in word_stat:
                word_stat[word] += 1
            else:
                word_stat[word] = 1
    return word_stat

filename = input()
print(word_statistics(filename))
# Out:
# revisor.txt
# ...
